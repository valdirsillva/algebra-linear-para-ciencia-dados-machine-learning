# %% [markdown]
# <a href="https://colab.research.google.com/github/valdirsillva/algebra-linear-para-ciencia-dados-machine-learning/blob/main/%C3%81lgebra_para_Ci%C3%AAncia_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U sentence-transformers

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

matplotlib.__version__
# Out:
# '3.10.0'

# %%
import numpy as np
np.__version__
# Out:
# '1.26.4'

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
import sentence_transformers
from sentence_transformers import SentenceTransformer
sentence_transformers.__version__
# Out:
# '5.4.0'

# %%
# !pip install tensorflow==2.17.1

# %%
import os
os.kill(os.getpid(), 9)

# %%
import tensorflow as tf

tf.__version__
# Out:
# '2.17.1'

# %%
import torch
torch.__version__
# Out:
# '2.10.0+cpu'

# %% [markdown]
# ## Tensores

# %% [markdown]
# ## Escalares

# %%
3
# Out:
# 3

# %%
-2
# Out:
# -2

# %%
5/7
# Out:
# 0.7142857142857143

# %%
7**2
# Out:
# 49

# %%
7**3
# Out:
# 343

# %%
scalar = np.array(8)

# %%
print(scalar)
# Out:
# 8

# %%
type(scalar) # numpy.ndarray
# Out:
# numpy.ndarray

# %%
scalar.ndim
# Out:
# 0

# %% [markdown]
# ## Vetores

# %%
lista = [1, 2, 3]

# %%
print(lista)
# Out:
# [1, 2, 3]

# %%
type(lista)
# Out:
# list

# %%
lista * 2 # Acontecerá um merge da mesma lista
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
vector = np.array([1, 2, 3])

# %%
print(vector)
# Out:
# [1 2 3]

# %%
type(vector)
# Out:
# numpy.ndarray

# %%
vector.ndim # verifica o número de dimensões
# Out:
# 1

# %%
# Realizando operações matemática
vector * 2
# Out:
# array([2, 4, 6])
